# %%
# !pip install kaggle

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("syedalinaqvi/augmented-skin-conditions-image-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 273M/273M [00:52<00:00, 5.46MB/s]
# Extracting files...
# Path to dataset files: /Users/Diane/.cache/kagglehub/datasets/syedalinaqvi/augmented-skin-conditions-image-dataset/versions/1

# %%
import pandas as pd 
import os 

path = "/Users/Diane/.cache/kagglehub/datasets/syedalinaqvi/augmented-skin-conditions-image-dataset/versions/1"

print(os.listdir(path))
# Out:
# ['Skin_Conditions']

# %%
image_folder = os.path.join(path, "Skin_Conditions")
print(os.listdir(image_folder))
# Out:
# ['Carcinoma', 'Keratosis', 'Acne', 'Eczema', 'Rosacea', 'Milia']

# %%
image_paths = []
labels = []

for label in os.listdir(image_folder):
    label_folder = os.path.join(image_folder, label)
    if os.path.isdir(label_folder):  # make sure it’s a folder
        for filename in os.listdir(label_folder):
            if filename.lower().endswith((".jpg", ".jpeg", ".png")):
                image_paths.append(os.path.join(label_folder, filename))
                labels.append(label)

df = pd.DataFrame({
    "image_path": image_paths,
    "label": labels
})

print(df.head())
# Out:
#                                           image_path      label
# 0  /Users/Diane/.cache/kagglehub/datasets/syedali...  Carcinoma
# 1  /Users/Diane/.cache/kagglehub/datasets/syedali...  Carcinoma
# 2  /Users/Diane/.cache/kagglehub/datasets/syedali...  Carcinoma
# 3  /Users/Diane/.cache/kagglehub/datasets/syedali...  Carcinoma
# 4  /Users/Diane/.cache/kagglehub/datasets/syedali...  Carcinoma

# %% [markdown]
# ### tensor flow exploratory analysis
